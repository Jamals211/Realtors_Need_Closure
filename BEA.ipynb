# %%
import pandas as pd
import numpy as np
import requests
import json

from pprint import pprint
from pybea.client import BureauEconomicAnalysisClient
import datapungibea as dpb
import pprint

#Matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.lines as mlines
from matplotlib import style
style.use(['classic','dark_background'])

# pip install feedparser

# pip install datapungibea
# pip install python-bea

key='877C205C-C78D-4A39-8C4E-E36B818F3C33'

# Initalize the new Client.
bea_client = BureauEconomicAnalysisClient(api_key=f'{key}')

# %%
# UnderlyingGDPbyIndustry -Underlying Detail estimates of value added, gross output, and intermediate inputs by industry.
# InputOutput	-Make and use tables, direct requirements, and total requirements statistics.
# Regional 	-Detailed income and employment statistics by state, county, and metropolitan area. Detailed GDP statistics by state and metropolitan statistical area. Price parities statistics by state and MSA.

# NIPA	-NIPA tables with options.
# https://apps.bea.gov/iTable/iTable.cfm?ReqID=19&step=4&isuri=1&1921=flatfiles&3Place=Y#reqid=19&step=4&isuri=1&1921=flatfiles

# NIUnderlyingDetail	-NI Underlying Detail tables with options.
# FixedAssets	-Fixed Assets tables with options
# ITA	-International Transactions dataset by indicator, area or country, frequency, and year
# IntlServTrade  -International Services Trade dataset by type of service, trade direction, affiliation, area or country, and year
# IIP	-International Investment Position dataset by type of investment, component, frequency, and year
# GDPByIndustry	 -Estimates of value added, gross output, intermediate inputs, KLEMS, and employment statistics by industry
# MNE	-Direct Investment by direction of investment, series, classification, year, country, and industry; and activities of Multinational Enterprises (MNE) by direction of investment, ownership, bank/non-bank, series, classification, year, country, industry, and state.

# %%
# Per capita personal income (dollars)
url=f'https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&datasetname=Regional&TableName=SAINC1&GeoFIPS=STATE&LineCode=3&Year=2018,2019&ResultFormat=JSON'                           
r=requests.get(url)
d=json.loads(r.text)
eighteen=[item for item in d['BEAAPI']['Results']['Data'] if item['TimePeriod']=='2018']
nineteen=[item for item in d['BEAAPI']['Results']['Data'] if item['TimePeriod']=='2019']
nineteen_df=pd.DataFrame(nineteen)
nineteen_df
# Out:
#         Code GeoFips               GeoName TimePeriod  CL_UNIT UNIT_MULT  \
# 0   SAINC1-3   00000         United States       2019  Dollars         0
# 1   SAINC1-3   01000               Alabama       2019  Dollars         0
# 2   SAINC1-3   02000              Alaska *       2019  Dollars         0
# 3   SAINC1-3   04000               Arizona       2019  Dollars         0
# 4   SAINC1-3   05000              Arkansas       2019  Dollars         0
# 5   SAINC1-3   06000            California       2019  Dollars         0
# 6   SAINC1-3   08000              Colorado       2019  Dollars         0
# 7   SAINC1-3   09000           Connecticut       2019  Dollars         0
# 8   SAINC1-3   10000              Delaware       2019  Dollars         0
# 9   SAINC1-3   11000  District of Columbia       2019  Dollars         0
# 10  SAINC1-3   12000               Florida       2019  Dollars         0
# 11  SAINC1-3   13000               Georgia       2019  Dollars         0
# 12  SAINC1-3   15000              Hawaii *       2019  Dollars         0
# 13  SAINC1-3   16000                 Idaho       2019  Dollars         0
# 14  SAINC1-3   17000              Illinois       2019  Dollars         0
# 15  SAINC1-3   18000               Indiana       2019  Dollars         0
# 16  SAINC1-3   19000                  Iowa       2019  Dollars         0
# 17  SAINC1-3   20000                Kansas       2019  Dollars         0
# 18  SAINC1-3   21000              Kentucky       2019  Dollars         0
# 19  SAINC1-3   22000             Louisiana       2019  Dollars         0
# 20  SAINC1-3   23000                 Maine       2019  Dollars         0
# 21  SAINC1-3   24000              Maryland       2019  Dollars         0
# 22  SAINC1-3   25000         Massachusetts       2019  Dollars         0
# 23  SAINC1-3   26000              Michigan       2019  Dollars         0
# 24  SAINC1-3   27000             Minnesota       2019  Dollars         0
# 25  SAINC1-3   28000           Mississippi       2019  Dollars         0
# 26  SAINC1-3   29000              Missouri       2019  Dollars         0
# 27  SAINC1-3   30000               Montana       2019  Dollars         0
# 28  SAINC1-3   31000              Nebraska       2019  Dollars         0
# 29  SAINC1-3   32000                Nevada       2019  Dollars         0
# 30  SAINC1-3   33000         New Hampshire       2019  Dollars         0
# 31  SAINC1-3   34000            New Jersey       2019  Dollars         0
# 32  SAINC1-3   35000            New Mexico       2019  Dollars         0
# 33  SAINC1-3   36000              New York       2019  Dollars         0
# 34  SAINC1-3   37000        North Carolina       2019  Dollars         0
# 35  SAINC1-3   38000          North Dakota       2019  Dollars         0
# 36  SAINC1-3   39000                  Ohio       2019  Dollars         0
# 37  SAINC1-3   40000              Oklahoma       2019  Dollars         0
# 38  SAINC1-3   41000                Oregon       2019  Dollars         0
# 39  SAINC1-3   42000          Pennsylvania       2019  Dollars         0
# 40  SAINC1-3   44000          Rhode Island       2019  Dollars         0
# 41  SAINC1-3   45000        South Carolina       2019  Dollars         0
# 42  SAINC1-3   46000          South Dakota       2019  Dollars         0
# 43  SAINC1-3   47000             Tennessee       2019  Dollars         0
# 44  SAINC1-3   48000                 Texas       2019  Dollars         0
# 45  SAINC1-3   49000                  Utah       2019  Dollars         0
# 46  SAINC1-3   50000               Vermont       2019  Dollars         0
# 47  SAINC1-3   51000              Virginia       2019  Dollars         0
# 48  SAINC1-3   53000            Washington       2019  Dollars         0
# 49  SAINC1-3   54000         West Virginia       2019  Dollars         0
# 50  SAINC1-3   55000             Wisconsin       2019  Dollars         0
# 51  SAINC1-3   56000               Wyoming       2019  Dollars         0
# 52  SAINC1-3   91000           New England       2019  Dollars         0
# 53  SAINC1-3   92000               Mideast       2019  Dollars         0
# 54  SAINC1-3   93000           Great Lakes       2019  Dollars         0
# 55  SAINC1-3   94000                Plains       2019  Dollars         0
# 56  SAINC1-3   95000             Southeast       2019  Dollars         0
# 57  SAINC1-3   96000             Southwest       2019  Dollars         0
# 58  SAINC1-3   97000        Rocky Mountain       2019  Dollars         0
# 59  SAINC1-3   98000              Far West       2019  Dollars         0
#
#    DataValue NoteRef
# 0     56,490     NaN
# 1     44,145     NaN
# 2     62,806       *
# 3     46,058     NaN
# 4     44,629     NaN
# 5     66,619     NaN
# 6     61,157     NaN
# 7     77,289     NaN
# 8     54,485     NaN
# 9     83,406     NaN
# 10    52,426     NaN
# 11    48,236     NaN
# 12    57,015       *
# 13    45,968     NaN
# 14    58,764     NaN
# 15    48,678     NaN
# 16    51,865     NaN
# 17    53,426     NaN
# 18    43,770     NaN
# 19    47,460     NaN
# 20    50,634     NaN
# 21    64,640     NaN
# 22    74,187     NaN
# 23    49,228     NaN
# 24    58,834     NaN
# 25    38,914     NaN
# 26    48,656     NaN
# 27    49,747     NaN
# 28    54,515     NaN
# 29    51,161     NaN
# 30    63,502     NaN
# 31    70,471     NaN
# 32    43,326     NaN
# 33    71,717     NaN
# 34    47,766     NaN
# 35    57,232     NaN
# 36    50,199     NaN
# 37    47,341     NaN
# 38    53,191     NaN
# 39    58,032     NaN
# 40    56,361     NaN
# 41    45,438     NaN
# 42    53,962     NaN
# 43    48,684     NaN
# 44    52,813     NaN
# 45    48,939     NaN
# 46    55,293     NaN
# 47    59,657     NaN
# 48    64,758     NaN
# 49    42,315     NaN
# 50    53,227     NaN
# 51    62,189     NaN
# 52    69,754     NaN
# 53    66,855     NaN
# 54    52,464     NaN
# 55    53,509     NaN
# 56    49,159     NaN
# 57    50,670     NaN
# 58    54,873     NaN
# 59    64,236     NaN

# %%
url=f"https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&DataSetName=NIPA&TableName=T20600&Frequency=M&Year=2015,2016&ResultFormat=JSON"                          
r = requests.get(url)
d = json.loads(r.text) 
d
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'YEAR',
#      'ParameterValue': '2015,2016'},
#     {'ParameterName': 'TABLENAME', 'ParameterValue': 'T20600'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'NIPA'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'FREQUENCY', 'ParameterValue': 'M'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'},
#     {'ParameterName': 'ShowMillions', 'ParameterValue': 'N'}]},
#   'Results': {'Statistic': 'NIPA Table',
#    'UTCProductionTime': '2021-01-15T20:30:57.200',
#    'Dimensions': [{'Ordinal': '1',
#      'Name': 'TableName',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '2',
#      'Name': 'SeriesCode',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '3',
#      'Name': 'LineNumber',
#      'DataType': 'numeric',
#      'IsValue': '0'},
#     {'Ordinal': '4',
#      'Name': 'LineDescription',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '5',
#      'Name': 'TimePeriod',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '6', 'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#     {'Ordinal': '7',
#      'Name': 'UNIT_MULT',
#      'DataType': 'numeric',
#      'IsValue': '0'},
#     {'Ordinal': '8',
#      'Name': 'METRIC_NAME',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '9',
#      'Name': 'DataValue',
#      'DataType': 'numeric',
#      'IsValue': '1'}],
#    'Data': [{'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,470,587',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,555,375',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,553,966',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,609,799',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,680,778',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,723,301',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,773,143',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,812,046',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,834,059',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,870,357',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,876,643',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,930,823',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,957,214',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,958,484',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '15,996,657',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,035,579',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,057,944',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,103,276',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,168,245',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,205,653',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,274,657',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,341,308',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,382,249',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A065RC',
#      'LineNumber': '1',
#      'LineDescription': 'Personal income',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '16,447,308',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,529,133',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,570,758',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,591,656',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,625,516',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,677,202',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,695,751',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,729,551',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,757,635',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,767,967',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,802,454',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,811,191',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,834,213',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,848,649',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,841,393',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,861,099',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,888,310',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,893,272',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,927,823',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,975,832',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '9,981,016',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '10,030,274',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '10,075,013',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '10,100,691',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A033RC',
#      'LineNumber': '2',
#      'LineDescription': 'Compensation of employees',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '10,142,911',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,717,865',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,752,202',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,768,485',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,796,334',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,840,675',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,855,353',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,883,998',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,908,503',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,916,435',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,946,613',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,953,493',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,973,833',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,990,960',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '7,983,183',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,000,619',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,024,747',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,028,681',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,058,402',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,100,759',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,103,281',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,146,222',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,185,065',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,206,027',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A034RC',
#      'LineNumber': '3',
#      'LineDescription': 'Wages and salaries',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '8,241,596',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,457,620',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,488,688',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,502,669',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,525,792',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,567,709',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,579,989',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,605,469',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,627,845',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,635,045',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,662,665',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,666,543',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,684,687',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,699,584',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,688,885',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,702,707',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,724,377',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,725,553',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,753,620',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,788,756',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,789,834',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,828,912',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,866,412',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,885,407',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A132RC',
#      'LineNumber': '4',
#      'LineDescription': 'Private industries',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '6,917,177',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,260,245',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,263,514',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,265,815',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,270,542',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,272,966',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,275,365',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,278,529',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,280,658',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,281,390',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,283,948',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,286,949',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,289,145',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,291,376',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,294,298',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,297,912',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,300,370',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,303,128',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,304,782',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,312,002',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,313,448',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,317,310',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,318,653',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,320,620',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B202RC',
#      'LineNumber': '5',
#      'LineDescription': 'Government',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,324,419',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,811,268',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,818,557',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,823,172',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,829,182',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,836,526',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,840,398',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,845,554',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,849,132',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,851,532',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,855,841',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,857,698',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,860,380',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,857,689',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,858,209',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,860,481',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,863,563',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,864,591',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,869,421',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,875,073',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,877,735',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,884,051',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,889,949',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,894,665',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A038RC',
#      'LineNumber': '6',
#      'LineDescription': 'Supplements to wages and salaries',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,901,315',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,251,884',
#      'NoteRef': 'T20600,T20600.1'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,256,679',
#      'NoteRef': 'T20600,T20600.1'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,260,011',
#      'NoteRef': 'T20600,T20600.1'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,264,124',
#      'NoteRef': 'T20600,T20600.1'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,268,365',
#      'NoteRef': 'T20600,T20600.1'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,271,249',
#      'NoteRef': 'T20600,T20600.1'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Current Dollars',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '6',
#      'DataValue': '1,274,466',
#      'NoteRef': 'T20600,T20600.1'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B040RC',
#      'LineNumber': '7',
#      'LineDescription': 'Employer contributions for employee pension and insurance funds',
# ...
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,596',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,457',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,517',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,565',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,581',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,678',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,759',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,845',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,889',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '41,847',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,018',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,149',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,177',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,189',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,107',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,064',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,058',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,163',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,166',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,263',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,326',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,388',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'A229RX',
#      'LineNumber': '39',
#      'LineDescription': 'Chained (2012) dollars',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Ratio',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '0',
#      'DataValue': '42,440',
#      'NoteRef': 'T20600'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M01',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '319,904',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M02',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '320,053',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M03',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '320,215',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M04',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '320,390',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M05',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '320,574',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M06',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '320,769',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M07',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '320,982',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M08',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '321,205',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M09',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '321,428',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M10',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '321,641',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M11',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '321,834',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2015M12',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '322,020',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M01',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '322,196',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M02',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '322,353',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M03',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '322,513',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M04',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '322,685',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M05',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '322,867',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M06',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '323,061',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M07',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '323,265',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M08',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '323,473',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M09',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '323,680',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M10',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '323,876',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M11',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '324,052',
#      'NoteRef': 'T20600,T20600.6'},
#     {'TableName': 'T20600',
#      'SeriesCode': 'B230RC',
#      'LineNumber': '40',
#      'LineDescription': 'Population (midperiod, thousands)',
#      'TimePeriod': '2016M12',
#      'METRIC_NAME': 'Persons',
#      'CL_UNIT': 'Level',
#      'UNIT_MULT': '3',
#      'DataValue': '324,216',
#      'NoteRef': 'T20600,T20600.6'}],
#    'Notes': [{'NoteRef': 'T20600',
#      'NoteText': 'Table 2.6. Personal Income and Its Disposition, Monthly [Billions of dollars; months are seasonally adjusted at annual rates] - LastRevised: December 23, 2020'},
#     {'NoteRef': 'T20600.1',
#      'NoteText': '1. Includes actual employer contributions and actuarially imputed employer contributions to reflect benefits accrued by defined benefit pension plan participants through service to employers in the current period.'},
#     {'NoteRef': 'T20600.2',
#      'NoteText': '2. Social security benefits include old-age, survivors, and disability insurance benefits that are distributed from the federal old-age and survivors insurance trust fund and the disability insurance trust fund.'},
#     {'NoteRef': 'T20600.3',
#      'NoteText': '3. Medicare benefits include hospital and supplementary medical insurance benefits that are distributed from the federal hospital insurance trust fund and the supplementary medical insurance trust fund.'},
#     {'NoteRef': 'T20600.4',
#      'NoteText': '4. Consists of nonmortgage interest paid by households.  Note that mortgage interest paid by households is an expense item in the calculation of rental income of persons.'},
#     {'NoteRef': 'T20600.5',
#      'NoteText': '5. The current-dollar measure is deflated by the implicit price deflator for personal consumption expenditures.'},
#     {'NoteRef': 'T20600.6',
#      'NoteText': '6. Population is the total population of the United States, including the Armed Forces overseas and the institutionalized population. The monthly estimate is the average of estimates for the first of the month and the first of the following month; the annual and quarterly estimates are averages of the monthly estimates.'}]}}}

# %%
url=f"http://apps.bea.gov/api/data?&UserID={key}&method=GetData&DataSetName=MNE&Year=2018,2019&Country=650,699&DirectionOfInvestment=Outward&Classification=Country&ResultFormat=json"                          
r = requests.get(url)
d = json.loads(r.text) 
d
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'COUNTRY',
#      'ParameterValue': '650,699'},
#     {'ParameterName': 'YEAR', 'ParameterValue': '2018,2019'},
#     {'ParameterName': 'DIRECTIONOFINVESTMENT', 'ParameterValue': 'OUTWARD'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'MNE'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'CLASSIFICATION', 'ParameterValue': 'COUNTRY'},
#     {'ParameterName': 'GetFootnotes', 'ParameterValue': 'no'},
#     {'ParameterName': 'NonbankAffiliatesOnly', 'ParameterValue': '2'},
#     {'ParameterName': 'OwnershipLevel', 'ParameterValue': '2'},
#     {'ParameterName': 'SeriesID', 'ParameterValue': 'all'}]},
#   'Results': {'Table_Count': '6',
#    'rowTypeID': '4,10',
#    'InvestmentType': 'U.S. Direct Investment Abroad',
#    'DataType': 'Balance of Payments and Direct Investment Position Data',
#    'Entity': 'None',
#    'IndustryClassification': 'NAICS',
#    'YearList': '2018,2019',
#    'DIRECTIONOFINVESTMENT': 'OUTWARD',
#    'OwnershipLevel': '2',
#    'NonbankAffiliatesOnly': '2',
#    'Tables': '13,16,17,210,211,212',
#    'cnt': '24',
#    'Dimensions': [{'Ordinal': '1',
#      'Name': 'Year',
#      'DataType': 'numeric',
#      'IsValue': '0'},
#     {'Ordinal': '2',
#      'Name': 'SeriesID',
#      'DataType': 'numeric',
#      'IsValue': '0'},
#     {'Ordinal': '3',
#      'Name': 'SeriesName',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '4', 'Name': 'Row', 'DataType': 'string', 'IsValue': '0'},
#     {'Ordinal': '5', 'Name': 'Column', 'DataType': 'string', 'IsValue': '0'},
#     {'Ordinal': '6', 'Name': 'RowCode', 'DataType': 'string', 'IsValue': '0'},
#     {'Ordinal': '7',
#      'Name': 'ColumnCode',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '8',
#      'Name': 'TableScale',
#      'DataType': 'string',
#      'IsValue': '0'},
#     {'Ordinal': '9',
#      'Name': 'DataValueUnformatted',
#      'DataType': 'string',
#      'IsValue': '1'},
#     {'Ordinal': '10',
#      'Name': 'DataValue',
#      'DataType': 'string',
#      'IsValue': '1'}],
#    'Data': [{'Year': '2018',
#      'SeriesID': '33',
#      'SeriesName': 'Debt Instruments Outflows',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Debt Outflows',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '-46564',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '64.00',
#      'DataValue': '-46,564'},
#     {'Year': '2019',
#      'SeriesID': '33',
#      'SeriesName': 'Debt Instruments Outflows',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Debt Outflows',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '2194',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '64.00',
#      'DataValue': '2,194'},
#     {'Year': '2019',
#      'SeriesID': '32',
#      'SeriesName': 'Equity Outflows Other than Reinvestment of Earnings',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Equity Outflows',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '2456',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '64.00',
#      'DataValue': '2,456'},
#     {'Year': '2018',
#      'SeriesID': '32',
#      'SeriesName': 'Equity Outflows Other than Reinvestment of Earnings',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Equity Outflows',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '4087',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '64.00',
#      'DataValue': '4,087'},
#     {'Year': '2019',
#      'SeriesID': '25',
#      'SeriesName': 'Reinvestment of Earnings Without Current-Cost Adjustment',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Reinvestment of Earnings',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '48720',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '64.00',
#      'DataValue': '48,720'},
#     {'Year': '2018',
#      'SeriesID': '25',
#      'SeriesName': 'Reinvestment of Earnings Without Current-Cost Adjustment',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Reinvestment of Earnings',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '6409',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '64.00',
#      'DataValue': '6,409'},
#     {'Year': '2019',
#      'SeriesID': '33',
#      'SeriesName': 'Debt Instruments Outflows',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Debt Outflows',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '259',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '66.00',
#      'DataValue': '259'},
#     {'Year': '2018',
#      'SeriesID': '33',
#      'SeriesName': 'Debt Instruments Outflows',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Debt Outflows',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '913',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '66.00',
#      'DataValue': '913'},
#     {'Year': '2019',
#      'SeriesID': '32',
#      'SeriesName': 'Equity Outflows Other than Reinvestment of Earnings',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Equity Outflows',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '148',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '66.00',
#      'DataValue': '148'},
#     {'Year': '2018',
#      'SeriesID': '32',
#      'SeriesName': 'Equity Outflows Other than Reinvestment of Earnings',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Equity Outflows',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '223',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '66.00',
#      'DataValue': '223'},
#     {'Year': '2018',
#      'SeriesID': '25',
#      'SeriesName': 'Reinvestment of Earnings Without Current-Cost Adjustment',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Reinvestment of Earnings',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '5092',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '66.00',
#      'DataValue': '5,092'},
#     {'Year': '2019',
#      'SeriesID': '25',
#      'SeriesName': 'Reinvestment of Earnings Without Current-Cost Adjustment',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Reinvestment of Earnings',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '7047',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '66.00',
#      'DataValue': '7,047'},
#     {'Year': '2018',
#      'SeriesID': '31',
#      'SeriesName': 'Financial Outflow Transactions Without Current-Cost Adjustment',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Financial Outflows',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '-36068',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '192.00',
#      'DataValue': '-36,068'},
#     {'Year': '2019',
#      'SeriesID': '31',
#      'SeriesName': 'Financial Outflow Transactions Without Current-Cost Adjustment',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Financial Outflows',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '53370',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '192.00',
#      'DataValue': '53,370'},
#     {'Year': '2018',
#      'SeriesID': '27',
#      'SeriesName': 'Direct Investment Income Without Current-Cost Adjustment',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Income',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '107111',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '192.00',
#      'DataValue': '107,111'},
#     {'Year': '2019',
#      'SeriesID': '27',
#      'SeriesName': 'Direct Investment Income Without Current-Cost Adjustment',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Income',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '98589',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '192.00',
#      'DataValue': '98,589'},
#     {'Year': '2018',
#      'SeriesID': '30',
#      'SeriesName': 'U.S. Direct Investment Position Abroad on a Historical-Cost Basis',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Position',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '888133',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '192.00',
#      'DataValue': '888,133'},
#     {'Year': '2019',
#      'SeriesID': '30',
#      'SeriesName': 'U.S. Direct Investment Position Abroad on a Historical-Cost Basis',
#      'Row': 'Asia and Pacific',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Position',
#      'RowCode': '699',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '955361',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '192.00',
#      'DataValue': '955,361'},
#     {'Year': '2018',
#      'SeriesID': '31',
#      'SeriesName': 'Financial Outflow Transactions Without Current-Cost Adjustment',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Financial Outflows',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '6228',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '194.00',
#      'DataValue': '6,228'},
#     {'Year': '2019',
#      'SeriesID': '31',
#      'SeriesName': 'Financial Outflow Transactions Without Current-Cost Adjustment',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Financial Outflows',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '7454',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '194.00',
#      'DataValue': '7,454'},
#     {'Year': '2019',
#      'SeriesID': '27',
#      'SeriesName': 'Direct Investment Income Without Current-Cost Adjustment',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Income',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '11852',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '194.00',
#      'DataValue': '11,852'},
#     {'Year': '2018',
#      'SeriesID': '27',
#      'SeriesName': 'Direct Investment Income Without Current-Cost Adjustment',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Income',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '13309',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '194.00',
#      'DataValue': '13,309'},
#     {'Year': '2018',
#      'SeriesID': '30',
#      'SeriesName': 'U.S. Direct Investment Position Abroad on a Historical-Cost Basis',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Position',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '109332',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '194.00',
#      'DataValue': '109,332'},
#     {'Year': '2019',
#      'SeriesID': '30',
#      'SeriesName': 'U.S. Direct Investment Position Abroad on a Historical-Cost Basis',
#      'Row': 'China',
#      'ColumnGParent': 'None',
#      'ColumnParent': 'None',
#      'Column': 'Position',
#      'RowCode': '650',
#      'ColumnCode': '0000',
#      'ColumnParentCode': '0',
#      'ColumnGParentCode': '0',
#      'TableScale': 'Millions of Dollars',
#      'DataValueUnformatted': '116203',
#      'TableColumnDisplayOrder': '1.00',
#      'TableRowDisplayOrder': '194.00',
#      'DataValue': '116,203'}]}}}

# %%
df=pd.DataFrame(r)
df
# Out:
#                                                     0
# 0   b'{"BEAAPI":{"Request":{"RequestParam":[{"Para...
# 1   b'alue":"2018,2019"},{"ParameterName":"DIRECTI...
# 2   b'erValue":"JSON"},{"ParameterName":"USERID","...
# 3   b'E","ParameterValue":"MNE"},{"ParameterName":...
# 4   b'ue":"COUNTRY"},{"ParameterName":"GetFootnote...
# ..                                                ...
# 89  b'ColumnParentCode":"0","ColumnGParentCode":"0...
# 90  b'playOrder":"1.00","TableRowDisplayOrder":"19...
# 91  b't Investment Position Abroad on a Historical...
# 92  b'sition","RowCode":"650","ColumnCode":"0000",...
# 93  b'ataValueUnformatted":"116203","TableColumnDi...
#
# [94 rows x 1 columns]

# %%
# token_file=open('token.txt', 'r')
# token=token_file.read()
url='https://apps.bea.gov/api/data'
payload={"UserID": key, 'method':'GETDATASETLIST', 'ResultFormat':'JSON'}
r=requests.get(url, params=payload)
resp=r.json()

# %%
datasets=resp['BEAAPI']['Results']['Dataset']
for dset in datasets:
    print(f"{dset['DatasetName']}:{dset['DatasetDescription']}")
# Out:
# NIPA:Standard NIPA tables
# NIUnderlyingDetail:Standard NI underlying detail tables
# MNE:Multinational Enterprises
# FixedAssets:Standard Fixed Assets tables
# ITA:International Transactions Accounts
# IIP:International Investment Position
# InputOutput:Input-Output Data
# IntlServTrade:International Services Trade
# GDPbyIndustry:GDP by Industry
# Regional:Regional data sets
# UnderlyingGDPbyIndustry:Underlying GDP by Industry
# APIDatasetMetaData:Metadata about other API datasets

# %%
# # Grab the Dataset List.
# dataset_list = bea_client.get_dataset_list()
# pprint(dataset_list)

# %%
dataset_name='GDPbyIndustry'
payload={'UserID':key, 'method':'getparameterlist',
        'DatasetName':dataset_name, "ResultFormat": 'JSON'}
r=requests.get(url, params=payload)
resp=r.json()

# %%
resp
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'METHOD',
#      'ParameterValue': 'GETPARAMETERLIST'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'GDPBYINDUSTRY'}]},
#   'Results': {'Parameter': [{'ParameterName': 'Frequency',
#      'ParameterDataType': 'string',
#      'ParameterDescription': 'A - Annual, Q-Quarterly',
#      'ParameterIsRequiredFlag': '1',
#      'ParameterDefaultValue': '',
#      'MultipleAcceptedFlag': '1',
#      'AllValue': 'ALL'},
#     {'ParameterName': 'Industry',
#      'ParameterDataType': 'string',
#      'ParameterDescription': 'List of industries to retrieve (ALL for All)',
#      'ParameterIsRequiredFlag': '1',
#      'ParameterDefaultValue': '',
#      'MultipleAcceptedFlag': '1',
#      'AllValue': 'ALL'},
#     {'ParameterName': 'TableID',
#      'ParameterDataType': 'integer',
#      'ParameterDescription': 'The unique GDP by Industry table identifier (ALL for All)',
#      'ParameterIsRequiredFlag': '1',
#      'ParameterDefaultValue': '',
#      'MultipleAcceptedFlag': '1',
#      'AllValue': 'ALL'},
#     {'ParameterName': 'Year',
#      'ParameterDataType': 'integer',
#      'ParameterDescription': 'List of year(s) of data to retrieve (ALL for All)',
#      'ParameterIsRequiredFlag': '1',
#      'ParameterDefaultValue': '',
#      'MultipleAcceptedFlag': '1',
#      'AllValue': 'ALL'}]}}}

# %%
paramlist=resp['BEAAPI']['Results']['Parameter']
for par in paramlist:
    print(f"{par['ParameterName']}:{par['ParameterDescription']}")
# Out:
# Frequency:A - Annual, Q-Quarterly
# Industry:List of industries to retrieve (ALL for All)
# TableID:The unique GDP by Industry table identifier (ALL for All)
# Year:List of year(s) of data to retrieve (ALL for All)

# %%
paramlist
# Out:
# [{'ParameterName': 'Frequency',
#   'ParameterDataType': 'string',
#   'ParameterDescription': 'A - Annual, Q-Quarterly',
#   'ParameterIsRequiredFlag': '1',
#   'ParameterDefaultValue': '',
#   'MultipleAcceptedFlag': '1',
#   'AllValue': 'ALL'},
#  {'ParameterName': 'Industry',
#   'ParameterDataType': 'string',
#   'ParameterDescription': 'List of industries to retrieve (ALL for All)',
#   'ParameterIsRequiredFlag': '1',
#   'ParameterDefaultValue': '',
#   'MultipleAcceptedFlag': '1',
#   'AllValue': 'ALL'},
#  {'ParameterName': 'TableID',
#   'ParameterDataType': 'integer',
#   'ParameterDescription': 'The unique GDP by Industry table identifier (ALL for All)',
#   'ParameterIsRequiredFlag': '1',
#   'ParameterDefaultValue': '',
#   'MultipleAcceptedFlag': '1',
#   'AllValue': 'ALL'},
#  {'ParameterName': 'Year',
#   'ParameterDataType': 'integer',
#   'ParameterDescription': 'List of year(s) of data to retrieve (ALL for All)',
#   'ParameterIsRequiredFlag': '1',
#   'ParameterDefaultValue': '',
#   'MultipleAcceptedFlag': '1',
#   'AllValue': 'ALL'}]

# %%
payload={"UserID":key, "method":"getparametervalaues",
        "DatasetName": dataset_name, "ParameterName": "TableID",
        "ResultFormat":"JSON"}
r=requests.get(url, params=payload)
resp=r.json()

# %%
resp
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'METHOD',
#      'ParameterValue': 'GETPARAMETERVALAUES'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'GDPBYINDUSTRY'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'PARAMETERNAME', 'ParameterValue': 'TABLEID'}]},
#   'Results': {'Error': {'APIErrorCode': '11',
#     'APIErrorDescription': 'The Method requested does not exist - valid choices are GetDatasetList, GetParameterList, GetParameterValues, and GetData'}}}}

# %%
url=f'https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&DataSetName=NIPA&TableName=T10101&Frequency=A,Q&Year=ALL&ResultFormat=JSON'
r=requests.get(url, params=payload)
resp=r.json()
resp
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'TABLENAME',
#      'ParameterValue': 'T10101'},
#     {'ParameterName': 'PARAMETERNAME', 'ParameterValue': 'TABLEID'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33,877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'NIPA,GDPBYINDUSTRY'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON,JSON'},
#     {'ParameterName': 'METHOD',
#      'ParameterValue': 'GETDATA,GETPARAMETERVALAUES'},
#     {'ParameterName': 'YEAR', 'ParameterValue': 'ALL'},
#     {'ParameterName': 'FREQUENCY', 'ParameterValue': 'A,Q'}]},
#   'Results': {'Error': {'APIErrorCode': '11',
#     'APIErrorDescription': 'The Method requested does not exist - valid choices are GetDatasetList, GetParameterList, GetParameterValues, and GetData'}}}}

# %%
# Percent change in Real Gross Domestic Product
url=f'https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&datasetname=Regional&TableName=CAINC1&LineCode=3&GeoFIPS=DE&Year=2014&ResultFormat=JSON'                           

r=requests.get(url)
d=json.loads(r.text)
d
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'LINECODE', 'ParameterValue': '3'},
#     {'ParameterName': 'GEOFIPS', 'ParameterValue': 'DE'},
#     {'ParameterName': 'YEAR', 'ParameterValue': '2014'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'REGIONAL'},
#     {'ParameterName': 'TABLENAME', 'ParameterValue': 'CAINC1'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'}]},
#   'Results': {'Statistic': 'Per capita personal income',
#    'UnitOfMeasure': 'Dollars',
#    'PublicTable': 'CAINC1 Personal Income Summary: Personal Income, Population, Per Capita Personal Income',
#    'UTCProductionTime': '2021-01-15T20:31:09.013',
#    'NoteRef': '2',
#    'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#     {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#    'Data': [{'Code': 'CAINC1-3',
#      'GeoFips': '10000',
#      'GeoName': 'Delaware',
#      'TimePeriod': '2014',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '45,993'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '10001',
#      'GeoName': 'Kent, DE',
#      'TimePeriod': '2014',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '37,323'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '10003',
#      'GeoName': 'New Castle, DE',
#      'TimePeriod': '2014',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '49,290'},
#     {'Code': 'CAINC1-3',
#      'GeoFips': '10005',
#      'GeoName': 'Sussex, DE',
#      'TimePeriod': '2014',
#      'CL_UNIT': 'Dollars',
#      'UNIT_MULT': '0',
#      'DataValue': '44,428'}],
#    'Notes': [{'NoteRef': '2',
#      'NoteText': 'Per capita personal income was computed using Census Bureau midyear population estimates. Estimates for 2010-2019 reflect county population estimates available as of March 2020.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget (OMB) bulletin no. 20-01 issued March 6, 2020.'},
#     {'NoteRef': 'Note.',
#      'NoteText': 'All dollar estimates are in thousands of current dollars (not adjusted for inflation). Calculations are performed on unrounded data.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Last updated: November 17, 2020-- new statistics for 2019; revised statistics for 2010-2018.'}]}}}

# %%
x=[item for item in d['BEAAPI']['Results']['Dimensions']]
# d['BEAAPI']['Results']
x
# Out:
# [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#  {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#  {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#  {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#  {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#  {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#  {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}]

# %%
df=pd.DataFrame(x)
df
# Out:
#          Name DataType IsValue
# 0        Code   string       0
# 1     GeoFips   string       0
# 2     GeoName   string       0
# 3  TimePeriod   string       0
# 4   DataValue  numeric       1
# 5     CL_UNIT   string       0
# 6   UNIT_MULT  numeric       0

# %%
name='RegionalIncome'
payload={"UserID":key, "method":"GetData",
        "DatasetName": 'RegionalIncome', "ParameterName": "CA1",
        "ResultFormat":"JSON"}
r=requests.get(url, params=payload)
d=json.loads(r.text)
d
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'TABLENAME',
#      'ParameterValue': 'CAINC1'},
#     {'ParameterName': 'PARAMETERNAME', 'ParameterValue': 'CA1'},
#     {'ParameterName': 'GEOFIPS', 'ParameterValue': 'DE'},
#     {'ParameterName': 'YEAR', 'ParameterValue': '2014'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33,877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'DATASETNAME',
#      'ParameterValue': 'REGIONAL,REGIONALINCOME'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON,JSON'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA,GETDATA'},
#     {'ParameterName': 'LINECODE', 'ParameterValue': '3'}]},
#   'Results': {'Error': {'APIErrorCode': '11',
#     'APIErrorDescription': 'The Method requested does not exist - valid choices are GetDatasetList, GetParameterList, GetParameterValues, and GetData'}}}}

# %% [markdown]
# # NIPA-National Income and Product Accounts (Value and compositon of US production and incomes generated in producing it)

# %%
# Percent Change in Real GPD
url=f'https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&datasetname=NIPA&TableName=T10101&Frequency=A,Q&Year=ALL&ResultFormat=JSON'                           
r=requests.get(url)
d=json.loads(r.text)
eighteen=[item for item in d['BEAAPI']['Results']['Data'] if item['TimePeriod']=='2018']
nineteen=[item for item in d['BEAAPI']['Results']['Data'] if item['TimePeriod']=='2019']
nineteen_df=pd.DataFrame(nineteen)
nineteen_df.head()
# Out:
#   TableName SeriesCode LineNumber                    LineDescription  \
# 0    T10101     A191RL          1             Gross domestic product
# 1    T10101     DPCERL          2  Personal consumption expenditures
# 2    T10101     DGDSRL          3                              Goods
# 3    T10101     DDURRL          4                      Durable goods
# 4    T10101     DNDGRL          5                   Nondurable goods
#
#   TimePeriod            METRIC_NAME                      CL_UNIT UNIT_MULT  \
# 0       2019  Fisher Quantity Index  Percent change, annual rate         0
# 1       2019  Fisher Quantity Index  Percent change, annual rate         0
# 2       2019  Fisher Quantity Index  Percent change, annual rate         0
# 3       2019  Fisher Quantity Index  Percent change, annual rate         0
# 4       2019  Fisher Quantity Index  Percent change, annual rate         0
#
#   DataValue NoteRef
# 0       2.2  T10101
# 1       2.4  T10101
# 2       3.7  T10101
# 3       4.8  T10101
# 4       3.1  T10101

# %%
# Percent Change in Real GPD
url=f'https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&datasetname=NIPA&TableName=T20600&Frequency=M&Year=2015,2016&ResultFormat=JSON'                      
r=requests.get(url)
d=json.loads(r.text)
Income=[item for item in d['BEAAPI']['Results']['Dimensions']]
Income_df=pd.DataFrame(Income)
Income_df
# Out:
#   Ordinal             Name DataType IsValue
# 0       1        TableName   string       0
# 1       2       SeriesCode   string       0
# 2       3       LineNumber  numeric       0
# 3       4  LineDescription   string       0
# 4       5       TimePeriod   string       0
# 5       6          CL_UNIT   string       0
# 6       7        UNIT_MULT  numeric       0
# 7       8      METRIC_NAME   string       0
# 8       9        DataValue  numeric       1

# %%
# Table Parameter - Specific NIPA Table (need combination of TableName, Frequency, Year values)
# TableID Parameter - Discontinued
# Frequency Parameter - Multiple values allowed - "A,Q,M"

# GetParameterValues method and passing TableName 
# Year - "2002, 2003, 2004"

# %%
# Stock market as an alternative investment avenue
# https://apps.bea.gov/api/data/?&UserID=Your-36CharacterKey&method=GetData&DataSetName=FixedAssets&TableName=FAAt201&Year=ALL&ResultFormat=xml

# Data on Direct Investment and Multinaational Enterprises (MNEs)
# -Direct investment
# -Activites of Multinamtional Companies-AMNE-US parent enterprises and foreign affilitaes

# US direct invenstment in China and Asia
# url='https://apps.bea.gov/api/data/?&SeriesId=30&UserID= Your-36CharacterKey&method=GetData&DataSetName=MNE&Year=2012,2011&Country=650,699&DirectionOfInvestment=Outward&Classification=Country&ResultFormat=JSON'           

# US Direct investment in US from Germany in manufacturing
# url='https://apps.bea.gov/api/data/?&SeriesId=22,23,24,25,26,27&UserID= Your-36CharacterKey&method=GetData&DataSetName=MNE&Year=2013,2012,2011,2010&Country=308&Industry=3000&DirectionOfInvestment=Inward&Classification=CountryByIndustry&ResultFormat=JSON'         

# AMNE 
#Net Income Brazilian affiliates of US parent enterprises for all industries
# url='https://apps.bea.gov/api/data/?&UserID= Your-36CharacterKey&method=GetData&DataSetName=MNE&Year=2012,2011&Country=202&Industry=all&DirectionOfInvestment=Outward&Classification=CountryByIndustry&SeriesId=5,4&NonBankAffiliatesOnly=0&OwnershipLevel=0&ResultFormat=JSON'         

# Total employment of US affiliates of foreigned own enterprises in all countrtries
# url ='https://apps.bea.gov/api/data/?&UserID= Your-36CharacterKey&method=GetData&DataSetName=MNE&Year=2011&Country=all&Industry=0000&DirectionOfInvestment=Inward&Classification=Country&SeriesId=8&OwnershipLevel=0&NonbankAffiliatesOnly=0&GetFootnotes=Yes&ResultFormat=JSON'

# %%
# GDP By Industry
url=f'https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&DataSetName=GDPbyIndustry&Year=2012,2011&Industry=ALL&tableID=1&Frequency=A&ResultFormat=JSON' 
# url='https://apps.bea.gov/api/data/?&UserID=877C205C-C78D-4A39-8C4E-E36B818F3C33&method=GetData&DataSetName=GDPbyIndustry&Year=2012,2011&Industry=ALL&tableID=1&Frequency=A&ResultFormat=JSON'
r=requests.get(url)
d=json.loads(r.text)
GDP_Product=[item for item in d['BEAAPI']['Results']['Data']] 
GDP_Product_df=pd.DataFrame(GDP_Product) 
GDP_Product_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-e881fdb72726> in <module>
#       4 r=requests.get(url)
#       5 d=json.loads(r.text)
# ----> 6 GDP_Product=[item for item in d['BEAAPI']['Results']['Data']]
#       7 GDP_Product_df=pd.DataFrame(GDP_Product)
#       8 GDP_Product_df
#
# TypeError: list indices must be integers or slices, not str

# %%
url=f'https://apps.bea.gov/api/data/?&UserID={key}&method=GetData&DataSetName=GDPbyIndustry&Year=2010&Industry=11&tableID=ALL&Frequency=A,Q&ResultFormat=JSON'           
r=requests.get(url)
d=json.loads(r.text)
Ag=[item for item in d['BEAAPI']['Results']['Data']]
Ag_df=pd.DataFrame(Ag)
Ag_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-1bad1ba0c291> in <module>
#       2 r=requests.get(url)
#       3 d=json.loads(r.text)
# ----> 4 Ag=[item for item in d['BEAAPI']['Results']['Data']]
#       5 Ag_df=pd.DataFrame(Ag)
#       6 Ag_df
#
# TypeError: list indices must be integers or slices, not str

# %%
d
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'TABLEID',
#      'ParameterValue': '1'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': '877C205C-C78D-4A39-8C4E-E36B818F3C33'},
#     {'ParameterName': 'YEAR', 'ParameterValue': '2012,2011'},
#     {'ParameterName': 'FREQUENCY', 'ParameterValue': 'A'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'INDUSTRY', 'ParameterValue': 'ALL'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'GDPBYINDUSTRY'}]},
#   'Results': [{'Statistic': 'GDP by Industry Table',
#     'UTCProductionTime': '2021-01-15T20:48:40.723',
#     'Dimensions': [{'Ordinal': '1',
#       'Name': 'TableID',
#       'DataType': 'numeric',
#       'IsValue': '0'},
#      {'Ordinal': '2',
#       'Name': 'Frequency',
#       'DataType': 'string',
#       'IsValue': '0'},
#      {'Ordinal': '3', 'Name': 'Year', 'DataType': 'string', 'IsValue': '0'},
#      {'Ordinal': '4', 'Name': 'Quarter', 'DataType': 'string', 'IsValue': '0'},
#      {'Ordinal': '5',
#       'Name': 'Industry',
#       'DataType': 'string',
#       'IsValue': '0'},
#      {'Ordinal': '6',
#       'Name': 'IndustryDescription',
#       'DataType': 'string',
#       'IsValue': '0'},
#      {'Ordinal': '7',
#       'Name': 'DataValue',
#       'DataType': 'numeric',
#       'IsValue': '1'}],
#     'Data': [{'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '11',
#       'IndustrYDescription': 'Agriculture, forestry, fishing, and hunting',
#       'DataValue': '180.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '111CA',
#       'IndustrYDescription': 'Farms',
#       'DataValue': '152.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '113FF',
#       'IndustrYDescription': 'Forestry, fishing, and related activities',
#       'DataValue': '28.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '21',
#       'IndustrYDescription': 'Mining',
#       'DataValue': '356.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '211',
#       'IndustrYDescription': 'Oil and gas extraction',
#       'DataValue': '218.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '212',
#       'IndustrYDescription': 'Mining, except oil and gas',
#       'DataValue': '76.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '213',
#       'IndustrYDescription': 'Support activities for mining',
#       'DataValue': '61.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '22',
#       'IndustrYDescription': 'Utilities',
#       'DataValue': '287.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '23',
#       'IndustrYDescription': 'Construction',
#       'DataValue': '524.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '311FT',
#       'IndustrYDescription': 'Food and beverage and tobacco products',
#       'DataValue': '209.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '313TT',
#       'IndustrYDescription': 'Textile mills and textile product mills',
#       'DataValue': '15.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '315AL',
#       'IndustrYDescription': 'Apparel and leather and allied products',
#       'DataValue': '10.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '31G',
#       'IndustrYDescription': 'Manufacturing',
#       'DataValue': '1867.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '31ND',
#       'IndustrYDescription': 'Nondurable goods',
#       'DataValue': '852.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '321',
#       'IndustrYDescription': 'Wood products',
#       'DataValue': '23.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '322',
#       'IndustrYDescription': 'Paper products',
#       'DataValue': '53.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '323',
#       'IndustrYDescription': 'Printing and related support activities',
#       'DataValue': '38.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '324',
#       'IndustrYDescription': 'Petroleum and coal products',
#       'DataValue': '158.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '325',
#       'IndustrYDescription': 'Chemical products',
#       'DataValue': '304.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '326',
#       'IndustrYDescription': 'Plastics and rubber products',
#       'DataValue': '62.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '327',
#       'IndustrYDescription': 'Nonmetallic mineral products',
#       'DataValue': '38.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '331',
#       'IndustrYDescription': 'Primary metals',
#       'DataValue': '62.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '332',
#       'IndustrYDescription': 'Fabricated metal products',
#       'DataValue': '127.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '333',
#       'IndustrYDescription': 'Machinery',
#       'DataValue': '144.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '334',
#       'IndustrYDescription': 'Computer and electronic products',
#       'DataValue': '237.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '335',
#       'IndustrYDescription': 'Electrical equipment, appliances, and components',
#       'DataValue': '48.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '3361MV',
#       'IndustrYDescription': 'Motor vehicles, bodies and trailers, and parts',
#       'DataValue': '104.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '3364OT',
#       'IndustrYDescription': 'Other transportation equipment',
#       'DataValue': '126.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '337',
#       'IndustrYDescription': 'Furniture and related products',
#       'DataValue': '22.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '339',
#       'IndustrYDescription': 'Miscellaneous manufacturing',
#       'DataValue': '80.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '33DG',
#       'IndustrYDescription': 'Durable goods',
#       'DataValue': '1015.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '42',
#       'IndustrYDescription': 'Wholesale trade',
#       'DataValue': '934.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '441',
#       'IndustrYDescription': 'Motor vehicle and parts dealers',
#       'DataValue': '148.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '445',
#       'IndustrYDescription': 'Food and beverage stores',
#       'DataValue': '130.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '44RT',
#       'IndustrYDescription': 'Retail trade',
#       'DataValue': '871.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '452',
#       'IndustrYDescription': 'General merchandise stores',
#       'DataValue': '134.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '481',
#       'IndustrYDescription': 'Air transportation',
#       'DataValue': '84.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '482',
#       'IndustrYDescription': 'Rail transportation',
#       'DataValue': '36.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '483',
#       'IndustrYDescription': 'Water transportation',
#       'DataValue': '14.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '484',
#       'IndustrYDescription': 'Truck transportation',
#       'DataValue': '121.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '485',
#       'IndustrYDescription': 'Transit and ground passenger transportation',
#       'DataValue': '34.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '486',
#       'IndustrYDescription': 'Pipeline transportation',
#       'DataValue': '21.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '487OS',
#       'IndustrYDescription': 'Other transportation and support activities',
#       'DataValue': '93.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '48TW',
#       'IndustrYDescription': 'Transportation and warehousing',
#       'DataValue': '451.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '493',
#       'IndustrYDescription': 'Warehousing and storage',
#       'DataValue': '45.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '4A0',
#       'IndustrYDescription': 'Other retail',
#       'DataValue': '459.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '51',
#       'IndustrYDescription': 'Information',
#       'DataValue': '759.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '511',
#       'IndustrYDescription': 'Publishing industries, except internet (includes software)',
#       'DataValue': '194.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '512',
#       'IndustrYDescription': 'Motion picture and sound recording industries',
#       'DataValue': '84.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '513',
#       'IndustrYDescription': 'Broadcasting and telecommunications',
#       'DataValue': '366.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '514',
#       'IndustrYDescription': 'Data processing, internet publishing, and other information services',
#       'DataValue': '114.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '52',
#       'IndustrYDescription': 'Finance and insurance',
#       'DataValue': '1026.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '521CI',
#       'IndustrYDescription': 'Federal Reserve banks, credit intermediation, and related activities',
#       'DataValue': '455.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '523',
#       'IndustrYDescription': 'Securities, commodity contracts, and investments',
#       'DataValue': '173.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '524',
#       'IndustrYDescription': 'Insurance carriers and related activities',
#       'DataValue': '384.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '525',
#       'IndustrYDescription': 'Funds, trusts, and other financial vehicles',
#       'DataValue': '13.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '53',
#       'IndustrYDescription': 'Real estate and rental and leasing',
#       'DataValue': '2019.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '531',
#       'IndustrYDescription': 'Real estate',
#       'DataValue': '1856.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '532RL',
#       'IndustrYDescription': 'Rental and leasing services and lessors of intangible assets',
#       'DataValue': '162.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '54',
#       'IndustrYDescription': 'Professional, scientific, and technical services',
#       'DataValue': '1124.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '5411',
#       'IndustrYDescription': 'Legal services',
#       'DataValue': '215.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '5412OP',
#       'IndustrYDescription': 'Miscellaneous professional, scientific, and technical services',
#       'DataValue': '684.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '5415',
#       'IndustrYDescription': 'Computer systems design and related services',
#       'DataValue': '224.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '55',
#       'IndustrYDescription': 'Management of companies and enterprises',
#       'DataValue': '278.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '56',
#       'IndustrYDescription': 'Administrative and waste management services',
#       'DataValue': '454.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '561',
#       'IndustrYDescription': 'Administrative and support services',
#       'DataValue': '411.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '562',
#       'IndustrYDescription': 'Waste management and remediation services',
#       'DataValue': '42.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '6',
#       'IndustrYDescription': 'Educational services, health care, and social assistance',
#       'DataValue': '1354.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '61',
#       'IndustrYDescription': 'Educational services',
#       'DataValue': '206.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '62',
#       'IndustrYDescription': 'Health care and social assistance',
#       'DataValue': '1148.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '621',
#       'IndustrYDescription': 'Ambulatory health care services',
#       'DataValue': '554.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '622',
#       'IndustrYDescription': 'Hospitals',
#       'DataValue': '382.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '623',
#       'IndustrYDescription': 'Nursing and residential care facilities',
#       'DataValue': '123.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '624',
#       'IndustrYDescription': 'Social assistance',
#       'DataValue': '88.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '7',
#       'IndustrYDescription': 'Arts, entertainment, recreation, accommodation, and food services',
#       'DataValue': '580.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '71',
#       'IndustrYDescription': 'Arts, entertainment, and recreation',
#       'DataValue': '158.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '711AS',
#       'IndustrYDescription': 'Performing arts, spectator sports, museums, and related activities',
#       'DataValue': '92.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '713',
#       'IndustrYDescription': 'Amusements, gambling, and recreation industries',
#       'DataValue': '65.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '72',
#       'IndustrYDescription': 'Accommodation and food services',
#       'DataValue': '422.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '721',
#       'IndustrYDescription': 'Accommodation',
#       'DataValue': '121.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '722',
#       'IndustrYDescription': 'Food services and drinking places',
#       'DataValue': '300.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': '81',
#       'IndustrYDescription': 'Other services, except government',
#       'DataValue': '333.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'FIRE',
#       'IndustrYDescription': 'Finance, insurance, real estate, rental, and leasing',
#       'DataValue': '3045.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'G',
#       'IndustrYDescription': 'Government',
#       'DataValue': '2137.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GDP',
#       'IndustrYDescription': 'Gross domestic product',
#       'DataValue': '15542.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GF',
#       'IndustrYDescription': 'Federal',
#       'DataValue': '712.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GFE',
#       'IndustrYDescription': 'Government enterprises',
#       'DataValue': '52.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GFG',
#       'IndustrYDescription': 'General government',
#       'DataValue': '659.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GFGD',
#       'IndustrYDescription': 'National defense',
#       'DataValue': '407.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GFGN',
#       'IndustrYDescription': 'Nondefense',
#       'DataValue': '252.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GSL',
#       'IndustrYDescription': 'State and local',
#       'DataValue': '1424.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GSLE',
#       'IndustrYDescription': 'Government enterprises',
#       'DataValue': '111.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'GSLG',
#       'IndustrYDescription': 'General government',
#       'DataValue': '1313.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'HS',
#       'IndustrYDescription': 'Housing',
#       'DataValue': '1498.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'ICT',
#       'IndustrYDescription': 'Information-communications-technology-producing industries<sup>3</sup>',
#       'DataValue': '974.4',
#       'NoteRef': '1;1.3.A'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'ORE',
#       'IndustrYDescription': 'Other real estate',
#       'DataValue': '358.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'PGOOD',
#       'IndustrYDescription': 'Private goods-producing industries<sup>1</sup>',
#       'DataValue': '2929.3',
#       'NoteRef': '1;1.1.A'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'PROF',
#       'IndustrYDescription': 'Professional and business services',
#       'DataValue': '1856.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'PSERV',
#       'IndustrYDescription': 'Private services-producing industries<sup>2</sup>',
#       'DataValue': '10476.3',
#       'NoteRef': '1;1.2.A'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2011',
#       'Quarter': '2011',
#       'Industry': 'PVT',
#       'IndustrYDescription': 'Private industries',
#       'DataValue': '13405.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '11',
#       'IndustrYDescription': 'Agriculture, forestry, fishing, and hunting',
#       'DataValue': '179.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '111CA',
#       'IndustrYDescription': 'Farms',
#       'DataValue': '148.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '113FF',
#       'IndustrYDescription': 'Forestry, fishing, and related activities',
#       'DataValue': '30.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '21',
#       'IndustrYDescription': 'Mining',
#       'DataValue': '358.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '211',
#       'IndustrYDescription': 'Oil and gas extraction',
#       'DataValue': '223.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '212',
#       'IndustrYDescription': 'Mining, except oil and gas',
#       'DataValue': '66.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '213',
#       'IndustrYDescription': 'Support activities for mining',
#       'DataValue': '68.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '22',
#       'IndustrYDescription': 'Utilities',
#       'DataValue': '279.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '23',
#       'IndustrYDescription': 'Construction',
#       'DataValue': '553.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '311FT',
#       'IndustrYDescription': 'Food and beverage and tobacco products',
#       'DataValue': '219.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '313TT',
#       'IndustrYDescription': 'Textile mills and textile product mills',
#       'DataValue': '15.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '315AL',
#       'IndustrYDescription': 'Apparel and leather and allied products',
#       'DataValue': '10.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '31G',
#       'IndustrYDescription': 'Manufacturing',
#       'DataValue': '1927.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '31ND',
#       'IndustrYDescription': 'Nondurable goods',
#       'DataValue': '865.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '321',
#       'IndustrYDescription': 'Wood products',
#       'DataValue': '25.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '322',
#       'IndustrYDescription': 'Paper products',
#       'DataValue': '53.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '323',
#       'IndustrYDescription': 'Printing and related support activities',
#       'DataValue': '38.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '324',
#       'IndustrYDescription': 'Petroleum and coal products',
#       'DataValue': '158.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '325',
#       'IndustrYDescription': 'Chemical products',
#       'DataValue': '303.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '326',
#       'IndustrYDescription': 'Plastics and rubber products',
#       'DataValue': '67.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '327',
#       'IndustrYDescription': 'Nonmetallic mineral products',
#       'DataValue': '42.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '331',
#       'IndustrYDescription': 'Primary metals',
#       'DataValue': '65.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '332',
#       'IndustrYDescription': 'Fabricated metal products',
#       'DataValue': '137.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '333',
#       'IndustrYDescription': 'Machinery',
#       'DataValue': '152.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '334',
#       'IndustrYDescription': 'Computer and electronic products',
#       'DataValue': '240.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '335',
#       'IndustrYDescription': 'Electrical equipment, appliances, and components',
#       'DataValue': '52.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '3361MV',
#       'IndustrYDescription': 'Motor vehicles, bodies and trailers, and parts',
#       'DataValue': '115.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '3364OT',
#       'IndustrYDescription': 'Other transportation equipment',
#       'DataValue': '126.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '337',
#       'IndustrYDescription': 'Furniture and related products',
#       'DataValue': '22.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '339',
#       'IndustrYDescription': 'Miscellaneous manufacturing',
#       'DataValue': '81.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '33DG',
#       'IndustrYDescription': 'Durable goods',
#       'DataValue': '1061.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '42',
#       'IndustrYDescription': 'Wholesale trade',
#       'DataValue': '997.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '441',
#       'IndustrYDescription': 'Motor vehicle and parts dealers',
#       'DataValue': '161.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '445',
#       'IndustrYDescription': 'Food and beverage stores',
#       'DataValue': '131.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '44RT',
#       'IndustrYDescription': 'Retail trade',
#       'DataValue': '908.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '452',
#       'IndustrYDescription': 'General merchandise stores',
#       'DataValue': '133.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '481',
#       'IndustrYDescription': 'Air transportation',
#       'DataValue': '87.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '482',
#       'IndustrYDescription': 'Rail transportation',
#       'DataValue': '39.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '483',
#       'IndustrYDescription': 'Water transportation',
#       'DataValue': '13.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '484',
#       'IndustrYDescription': 'Truck transportation',
#       'DataValue': '128.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '485',
#       'IndustrYDescription': 'Transit and ground passenger transportation',
#       'DataValue': '36.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '486',
#       'IndustrYDescription': 'Pipeline transportation',
#       'DataValue': '25.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '487OS',
#       'IndustrYDescription': 'Other transportation and support activities',
#       'DataValue': '94.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '48TW',
#       'IndustrYDescription': 'Transportation and warehousing',
#       'DataValue': '472.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '493',
#       'IndustrYDescription': 'Warehousing and storage',
#       'DataValue': '47.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '4A0',
#       'IndustrYDescription': 'Other retail',
#       'DataValue': '482.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '51',
#       'IndustrYDescription': 'Information',
#       'DataValue': '759.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '511',
#       'IndustrYDescription': 'Publishing industries, except internet (includes software)',
#       'DataValue': '201.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '512',
#       'IndustrYDescription': 'Motion picture and sound recording industries',
#       'DataValue': '82.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '513',
#       'IndustrYDescription': 'Broadcasting and telecommunications',
#       'DataValue': '370.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '514',
#       'IndustrYDescription': 'Data processing, internet publishing, and other information services',
#       'DataValue': '104.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '52',
#       'IndustrYDescription': 'Finance and insurance',
#       'DataValue': '1162.8',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '521CI',
#       'IndustrYDescription': 'Federal Reserve banks, credit intermediation, and related activities',
#       'DataValue': '511.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '523',
#       'IndustrYDescription': 'Securities, commodity contracts, and investments',
#       'DataValue': '233.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '524',
#       'IndustrYDescription': 'Insurance carriers and related activities',
#       'DataValue': '405.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '525',
#       'IndustrYDescription': 'Funds, trusts, and other financial vehicles',
#       'DataValue': '12.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '53',
#       'IndustrYDescription': 'Real estate and rental and leasing',
#       'DataValue': '2098.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '531',
#       'IndustrYDescription': 'Real estate',
#       'DataValue': '1925.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '532RL',
#       'IndustrYDescription': 'Rental and leasing services and lessors of intangible assets',
#       'DataValue': '172.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '54',
#       'IndustrYDescription': 'Professional, scientific, and technical services',
#       'DataValue': '1188.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '5411',
#       'IndustrYDescription': 'Legal services',
#       'DataValue': '216.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '5412OP',
#       'IndustrYDescription': 'Miscellaneous professional, scientific, and technical services',
#       'DataValue': '719.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '5415',
#       'IndustrYDescription': 'Computer systems design and related services',
#       'DataValue': '252.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '55',
#       'IndustrYDescription': 'Management of companies and enterprises',
#       'DataValue': '302.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '56',
#       'IndustrYDescription': 'Administrative and waste management services',
#       'DataValue': '473.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '561',
#       'IndustrYDescription': 'Administrative and support services',
#       'DataValue': '431.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '562',
#       'IndustrYDescription': 'Waste management and remediation services',
#       'DataValue': '42.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '6',
#       'IndustrYDescription': 'Educational services, health care, and social assistance',
#       'DataValue': '1407.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '61',
#       'IndustrYDescription': 'Educational services',
#       'DataValue': '213.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '62',
#       'IndustrYDescription': 'Health care and social assistance',
#       'DataValue': '1193.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '621',
#       'IndustrYDescription': 'Ambulatory health care services',
#       'DataValue': '573.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '622',
#       'IndustrYDescription': 'Hospitals',
#       'DataValue': '398.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '623',
#       'IndustrYDescription': 'Nursing and residential care facilities',
#       'DataValue': '125.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '624',
#       'IndustrYDescription': 'Social assistance',
#       'DataValue': '96.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '7',
#       'IndustrYDescription': 'Arts, entertainment, recreation, accommodation, and food services',
#       'DataValue': '621.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '71',
#       'IndustrYDescription': 'Arts, entertainment, and recreation',
#       'DataValue': '171.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '711AS',
#       'IndustrYDescription': 'Performing arts, spectator sports, museums, and related activities',
#       'DataValue': '101.3',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '713',
#       'IndustrYDescription': 'Amusements, gambling, and recreation industries',
#       'DataValue': '69.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '72',
#       'IndustrYDescription': 'Accommodation and food services',
#       'DataValue': '450.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '721',
#       'IndustrYDescription': 'Accommodation',
#       'DataValue': '128.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '722',
#       'IndustrYDescription': 'Food services and drinking places',
#       'DataValue': '321.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': '81',
#       'IndustrYDescription': 'Other services, except government',
#       'DataValue': '348.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'FIRE',
#       'IndustrYDescription': 'Finance, insurance, real estate, rental, and leasing',
#       'DataValue': '3261.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'G',
#       'IndustrYDescription': 'Government',
#       'DataValue': '2159.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GDP',
#       'IndustrYDescription': 'Gross domestic product',
#       'DataValue': '16197.0',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GF',
#       'IndustrYDescription': 'Federal',
#       'DataValue': '713.9',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GFE',
#       'IndustrYDescription': 'Government enterprises',
#       'DataValue': '50.2',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GFG',
#       'IndustrYDescription': 'General government',
#       'DataValue': '663.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GFGD',
#       'IndustrYDescription': 'National defense',
#       'DataValue': '407.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GFGN',
#       'IndustrYDescription': 'Nondefense',
#       'DataValue': '256.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GSL',
#       'IndustrYDescription': 'State and local',
#       'DataValue': '1445.6',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GSLE',
#       'IndustrYDescription': 'Government enterprises',
#       'DataValue': '120.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'GSLG',
#       'IndustrYDescription': 'General government',
#       'DataValue': '1325.5',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'HS',
#       'IndustrYDescription': 'Housing',
#       'DataValue': '1531.1',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'ICT',
#       'IndustrYDescription': 'Information-communications-technology-producing industries<sup>3</sup>',
#       'DataValue': '985.4',
#       'NoteRef': '1;1.3.A'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'ORE',
#       'IndustrYDescription': 'Other real estate',
#       'DataValue': '394.4',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'PGOOD',
#       'IndustrYDescription': 'Private goods-producing industries<sup>1</sup>',
#       'DataValue': '3018.8',
#       'NoteRef': '1;1.1.A'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'PROF',
#       'IndustrYDescription': 'Professional and business services',
#       'DataValue': '1964.7',
#       'NoteRef': '1'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'PSERV',
#       'IndustrYDescription': 'Private services-producing industries<sup>2</sup>',
#       'DataValue': '11018.7',
#       'NoteRef': '1;1.2.A'},
#      {'TableID': '1',
#       'Frequency': 'A',
#       'Year': '2012',
#       'Quarter': '2012',
#       'Industry': 'PVT',
#       'IndustrYDescription': 'Private industries',
#       'DataValue': '14037.5',
#       'NoteRef': '1'}],
#     'Notes': [{'NoteRef': '1.1.A',
#       'NoteText': '1. Consists of agriculture, forestry, fishing, and hunting; mining; construction; and manufacturing.'},
#      {'NoteRef': '1.2.A',
#       'NoteText': '2. Consists of utilities; wholesale trade; retail trade; transportation and warehousing; information; finance, insurance, real estate, rental, and leasing; professional and business services; educational services, health care, and social assistance; arts, entertainment, recreation, accommodation, and food services; and other services, except government.'},
#      {'NoteRef': '1.3.A',
#       'NoteText': '3. Consists of computer and electronic product manufacturing (excluding navigational, measuring, electromedical, and control instruments manufacturing); software publishers; broadcasting and telecommunications; data processing, hosting and related services; internet publishing and broadcasting and web search portals; and computer systems design and related services.'},
#      {'NoteRef': '1.0.A',
#       'NoteText': 'Note. Detail may not add to total due to rounding.'},
#      {'NoteRef': '1',
#       'NoteText': 'Value Added by Industry [Billions of dollars]'}]}]}}
